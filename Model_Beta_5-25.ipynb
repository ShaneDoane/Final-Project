# %%
# !pip install flask-sqlalchemy
# Out:
# Requirement already satisfied: flask-sqlalchemy in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (2.5.1)
# Requirement already satisfied: SQLAlchemy>=0.8.0 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from flask-sqlalchemy) (1.4.36)
# Requirement already satisfied: Flask>=0.10 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from flask-sqlalchemy) (1.1.2)
# Requirement already satisfied: click>=5.1 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from Flask>=0.10->flask-sqlalchemy) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from Flask>=0.10->flask-sqlalchemy) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from Flask>=0.10->flask-sqlalchemy) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from Flask>=0.10->flask-sqlalchemy) (2.0.1)
# Requirement already satisfied: importlib-metadata in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from click>=5.1->Flask>=0.10->flask-sqlalchemy) (4.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=0.10->flask-sqlalchemy) (1.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from SQLAlchemy>=0.8.0->flask-sqlalchemy) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from importlib-metadata->click>=5.1->Flask>=0.10->flask-sqlalchemy) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from importlib-metadata->click>=5.1->Flask>=0.10->flask-sqlalchemy) (3.10.0.2)

# %%
# Import dependencies

# For data processing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# For ML
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# For Database connections
import sqlalchemy 
from sqlalchemy import create_engine, func
from sqlalchemy import inspect
# from sqlalchemy import session
import psycopg2
from sqlalchemy.ext.automap import automap_base

# %%
# Connect to Database - this will be done via config.py in the future
host = "group2022.cem6bfyajguw.us-east-2.rds.amazonaws.com"
database = "postgres"
user = 'postgres'
password = 'postgrespassword'

db_string = f"postgresql://{user}:{password}@{host}/{database}"

# %%
# Set up SQLAlchemy
engine = create_engine(db_string)
insp = inspect(engine)
insp.get_table_names()
# Out:
# ['teams',
#  'regular_season_detailed_results',
#  'all_game_results',
#  'conferences',
#  'rankings_with_team_names',
#  'conferences_with_team_names',
#  'sag_system',
#  'rankings']

# %%
# Teams raw DF
teams_df=pd.read_sql_table('teams', engine)
print(teams_df.shape)
teams_df.head()
# Out:
# (372, 4)
#    teamid     teamname  firstd1season  lastd1season
# 0    1101  Abilene Chr           2014          2022
# 1    1102    Air Force           1985          2022
# 2    1103        Akron           1985          2022
# 3    1104      Alabama           1985          2022
# 4    1105  Alabama A&M           2000          2022

# %%
# Rankings raw DF
rankings_df=pd.read_sql_table('rankings', engine)
print(rankings_df.shape)
rankings_df.head()
# Out:
# (4521720, 5)
#    season  rankingdaynum systemname  teamid  ordinalrank
# 0    2010            113        BPI    1315          332
# 1    2010            113        BPI    1316          238
# 2    2010            113        BPI    1317          145
# 3    2010            113        BPI    1318           73
# 4    2010            113        BPI    1319          206

# %%
# Checking ranking systems
rankings_df['systemname'].value_counts()
# Out:
# SAG    122047
# MOR    121057
# POM    118566
# DOK    105270
# WLK     97047
#         ...
# HRN       351
# CRW       351
# PMC       351
# BP5       345
# PH        326
# Name: systemname, Length: 187, dtype: int64

# %%
# We need to get just SAG ranks for simplicity
SAG_ranks = rankings_df.loc[rankings_df['systemname']=='SAG']
SAG_ranks.sample(5)
# Out:
#          season  rankingdaynum systemname  teamid  ordinalrank
# 2305430    2019             16        SAG    1402          229
# 817179     2013            133        SAG    1122          297
# 4185099    2009             36        SAG    1397           11
# 1271578    2015             93        SAG    1233           89
# 4271997    2009             93        SAG    1395          112

# %%
# Results raw DF

raw_results_df=pd.read_sql_table('regular_season_detailed_results', engine)
print(raw_results_df.shape)
raw_results_df.head()
# Out:
# (100423, 34)
#    season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  wfga  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  lfga3  lftm  lfta  lor  ldr  last  lto  lstl  lblk  lpf
# 0  ...     10    16    22   10   22     8   18     9     2   20
# 1  ...     24     9    20   20   25     7   12     8     6   16
# 2  ...     26    14    23   31   22     9   12     2     5   23
# 3  ...     22     8    15   17   20     9   19     4     3   23
# 4  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
raw_results_df.columns
# Out:
# Index(['season', 'daynum', 'wteamid', 'wscore', 'lteamid', 'lscore', 'wloc',
#        'numot', 'wfgm', 'wfga', 'wfgm3', 'wfga3', 'wftm', 'wfta', 'wor', 'wdr',
#        'wast', 'wto', 'wstl', 'wblk', 'wpf', 'lfgm', 'lfga', 'lfgm3', 'lfga3',
#        'lftm', 'lfta', 'lor', 'ldr', 'last', 'lto', 'lstl', 'lblk', 'lpf'],
#       dtype='object')

# %%
# We want to drop years before 2003, because rankings go to 2003. Also drop extra 'ordinalrank'
results_df = raw_results_df[raw_results_df['season']>=2003]
results_df.head()
# Out:
#    season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  wfga  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  lfga3  lftm  lfta  lor  ldr  last  lto  lstl  lblk  lpf
# 0  ...     10    16    22   10   22     8   18     9     2   20
# 1  ...     24     9    20   20   25     7   12     8     6   16
# 2  ...     26    14    23   31   22     9   12     2     5   23
# 3  ...     22     8    15   17   20     9   19     4     3   23
# 4  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %% [markdown]
# # Preprocessing & Feature Engineering

# %%
# Make a new column in SAG_Ranks called 'Season_Day_Team' that we will repeat in Results 

SAG_ranks['season-day-team'] = SAG_ranks['season'].map(str) + '-' + SAG_ranks['rankingdaynum'].map(str) + '-' + SAG_ranks['teamid'].map(str)
SAG_ranks.head()
# Out:
# /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       season  rankingdaynum systemname  teamid  ordinalrank season-day-team
# 6393    2010            113        SAG    1102          230   2010-113-1102
# 6394    2010            113        SAG    1103          101   2010-113-1103
# 6395    2010            113        SAG    1104           83   2010-113-1104
# 6396    2010            113        SAG    1105          334   2010-113-1105
# 6397    2010            113        SAG    1106          314   2010-113-1106

# %%
# Make new columns in SAG_Ranks called 'RankingWeek' and 'Season_Week_Team' because rankings only come out weekly

SAG_ranks['rankingweek'] = (SAG_ranks['rankingdaynum']/7).apply(np.ceil)

SAG_ranks['season-week-team'] = SAG_ranks['season'].map(str) + '-' + SAG_ranks['rankingweek'].map(str) + '-' + SAG_ranks['teamid'].map(str)
SAG_ranks.head()
# Out:
# /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       season  rankingdaynum systemname  teamid  ordinalrank season-day-team  \
# 6393    2010            113        SAG    1102          230   2010-113-1102
# 6394    2010            113        SAG    1103          101   2010-113-1103
# 6395    2010            113        SAG    1104           83   2010-113-1104
# 6396    2010            113        SAG    1105          334   2010-113-1105
# 6397    2010            113        SAG    1106          314   2010-113-1106
#
#       rankingweek season-week-team
# 6393         17.0   2010-17.0-1102
# 6394         17.0   2010-17.0-1103
# 6395         17.0   2010-17.0-1104
# 6396         17.0   2010-17.0-1105
# 6397         17.0   2010-17.0-1106

# %%
SAG_ranks.shape
# Out:
# (122047, 8)

# %%
# Make a new column in Results called 'WSeason_Day_Team' & 'LSeason_Day_Team' that we'll use for potential indices

results_df['wseason-Day-Team'] = results_df['season'].map(str) + '-' + results_df['daynum'].map(str) + '-' + results_df['wteamid'].map(str)
results_df['lseason-Day-Team'] = results_df['season'].map(str) + '-' + results_df['daynum'].map(str) + '-' + results_df['lteamid'].map(str)
results_df.head()
# Out:
#    season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  wfga  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  lfta  lor  ldr  last  lto  lstl  lblk  lpf  wseason-Day-Team  \
# 0  ...    22   10   22     8   18     9     2   20      2003-10-1104
# 1  ...    20   20   25     7   12     8     6   16      2003-10-1272
# 2  ...    23   31   22     9   12     2     5   23      2003-11-1266
# 3  ...    15   17   20     9   19     4     3   23      2003-11-1296
# 4  ...    27   21   15    12   10     7     1   14      2003-11-1400
#
#    lseason-Day-Team
# 0      2003-10-1328
# 1      2003-10-1393
# 2      2003-11-1437
# 3      2003-11-1457
# 4      2003-11-1208
#
# [5 rows x 36 columns]

# %%
# Make a new column in Results called 'WSeason_Week_Team' & 'LSeason_Week_Team' that we'll use for loc to pull in OrdinalRank for winning and losing team

results_df['weeknum'] = (results_df['daynum']/7).apply(np.ceil)

results_df['wseason-week-team'] = results_df['season'].map(str) + '-' + results_df['weeknum'].map(str) + '-' + results_df['wteamid'].map(str)
results_df['lseason-week-team'] = results_df['season'].map(str) + '-' + results_df['weeknum'].map(str) + '-' + results_df['lteamid'].map(str)
results_df.head()
# Out:
#    season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  wfga  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  last  lto  lstl  lblk  lpf  wseason-Day-Team  lseason-Day-Team  \
# 0  ...     8   18     9     2   20      2003-10-1104      2003-10-1328
# 1  ...     7   12     8     6   16      2003-10-1272      2003-10-1393
# 2  ...     9   12     2     5   23      2003-11-1266      2003-11-1437
# 3  ...     9   19     4     3   23      2003-11-1296      2003-11-1457
# 4  ...    12   10     7     1   14      2003-11-1400      2003-11-1208
#
#    weeknum  wseason-week-team  lseason-week-team
# 0      2.0      2003-2.0-1104      2003-2.0-1328
# 1      2.0      2003-2.0-1272      2003-2.0-1393
# 2      2.0      2003-2.0-1266      2003-2.0-1437
# 3      2.0      2003-2.0-1296      2003-2.0-1457
# 4      2.0      2003-2.0-1400      2003-2.0-1208
#
# [5 rows x 39 columns]

# %%
# Merging winning team rankings on season-week-team. There will be NA's for Rank bc of beginning and end of season

results_df = results_df.merge(SAG_ranks[['season-week-team','ordinalrank']], how='left', left_on='wseason-week-team', right_on='season-week-team').drop(columns=['season-week-team'])

results_df.sample(5)
# Out:
#        season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 65318    2014     122     1437      77     1462      70    A      0    23
# 62774    2014      68     1223      98     1322      97    H      0    35
# 29381    2008      75     1131      59     1392      52    A      0    19
# 51410    2012      59     1430      42     1214      40    N      0    15
# 75766    2016     110     1138      88     1132      74    H      0    29
#
#        wfga  ...  lto  lstl  lblk  lpf  wseason-Day-Team  lseason-Day-Team  \
# 65318    49  ...   10     5     2   22     2014-122-1437     2014-122-1462
# 62774    65  ...   12     9     4   22      2014-68-1223      2014-68-1322
# 29381    52  ...   12     5     4   20      2008-75-1131      2008-75-1392
# 51410    61  ...   11     5    13   15      2012-59-1430      2012-59-1214
# 75766    59  ...   18     6     1   26     2016-110-1138     2016-110-1132
#
#        weeknum  wseason-week-team  lseason-week-team  ordinalrank
# 65318     18.0     2014-18.0-1437     2014-18.0-1462          3.0
# 62774     10.0     2014-10.0-1223     2014-10.0-1322        335.0
# 29381     11.0     2008-11.0-1131     2008-11.0-1392        269.0
# 51410      9.0      2012-9.0-1430      2012-9.0-1214        238.0
# 75766     16.0     2016-16.0-1138     2016-16.0-1132        143.0
#
# [5 rows x 40 columns]

# %%
# Rename OrdinalRank to WRank
results_df.rename(columns={'ordinalrank': 'wrank'},inplace=True)
results_df.sample(5)
# Out:
#         season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 103325    2022      11     1458      72     1453      34    H      0    24
# 9871      2004     115     1194      95     1144      80    H      0    30
# 96953     2020      82     1202      78     1154      54    A      0    27
# 18343     2006      82     1362      62     1339      50    H      0    25
# 55502     2013      18     1153      78     1235      70    N      0    25
#
#         wfga  ...  lto  lstl  lblk  lpf  wseason-Day-Team  lseason-Day-Team  \
# 103325    64  ...   12     3     4   20      2022-11-1458      2022-11-1453
# 9871      73  ...   10     9     3   23     2004-115-1194     2004-115-1144
# 96953     63  ...   21     5     6   20      2020-82-1202      2020-82-1154
# 18343     63  ...   16     1     2   17      2006-82-1362      2006-82-1339
# 55502     60  ...   18     6     2   20      2013-18-1153      2013-18-1235
#
#         weeknum  wseason-week-team  lseason-week-team  wrank
# 103325      2.0      2022-2.0-1458      2022-2.0-1453    NaN
# 9871       17.0     2004-17.0-1194     2004-17.0-1144  262.0
# 96953      12.0     2020-12.0-1202     2020-12.0-1154   93.0
# 18343      12.0     2006-12.0-1362     2006-12.0-1339  176.0
# 55502       3.0      2013-3.0-1153      2013-3.0-1235   44.0
#
# [5 rows x 40 columns]

# %%
# Merging losing team rankings on season-week-team. There will be NA's for Rank bc of beginning and end of season

results_df = results_df.merge(SAG_ranks[['season-week-team','ordinalrank']], how='left', left_on='lseason-week-team', right_on='season-week-team').drop(columns=['season-week-team'])

results_df.sample(5)
# Out:
#         season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 7813      2004      56     1395      99     1212      71    H      0    34
# 113176    2021      74     1421      83     1149      75    H      0    31
# 89943     2017      47     1338      83     1349      73    H      0    29
# 56267     2011      80     1404      79     1369      69    H      0    27
# 19121     2005     129     1438      66     1274      65    N      0    22
#
#         wfga  ...  lstl  lblk  lpf  wseason-Day-Team  lseason-Day-Team  \
# 7813      55  ...     9     0   29      2004-56-1395      2004-56-1212
# 113176    58  ...     4     3    0      2021-74-1421      2021-74-1149
# 89943     45  ...     8     2   18      2017-47-1338      2017-47-1349
# 56267     65  ...     3    10   20      2011-80-1404      2011-80-1369
# 19121     50  ...     3     0   23     2005-129-1438     2005-129-1274
#
#         weeknum  wseason-week-team  lseason-week-team  wrank  ordinalrank
# 7813        8.0      2004-8.0-1395      2004-8.0-1212  207.0        310.0
# 113176     11.0     2021-11.0-1421     2021-11.0-1149  244.0        321.0
# 89943       7.0      2017-7.0-1338      2017-7.0-1349   70.0        109.0
# 56267      12.0     2011-12.0-1404     2011-12.0-1369  318.0        319.0
# 19121      19.0     2005-19.0-1438     2005-19.0-1274   78.0         58.0
#
# [5 rows x 41 columns]

# %%
# Rename OrdinalRank to LRank
results_df.rename(columns={'ordinalrank': 'lrank'},inplace=True)
results_df.sample(5)
# Out:
#         season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 62571     2012      91     1459      82     1441      56    H      0    32
# 67792     2013      79     1191      66     1133      56    H      0    27
# 42538     2009      75     1151      82     1441      75    H      0    25
# 113964    2021      94     1429      69     1201      53    A      0    26
# 16414     2005      73     1264      78     1310      72    H      0    27
#
#         wfga  ...  lstl  lblk  lpf  wseason-Day-Team  lseason-Day-Team  \
# 62571     54  ...     5     1   14      2012-91-1459      2012-91-1441
# 67792     54  ...     5     2   17      2013-79-1191      2013-79-1133
# 42538     57  ...     9     4   33      2009-75-1151      2009-75-1441
# 113964    52  ...     6     3    0      2021-94-1429      2021-94-1201
# 16414     62  ...     6     4   20      2005-73-1264      2005-73-1310
#
#         weeknum  wseason-week-team  lseason-week-team  wrank  lrank
# 62571      13.0     2012-13.0-1459     2012-13.0-1441  183.0  244.0
# 67792      12.0     2013-12.0-1191     2013-12.0-1133  120.0  141.0
# 42538      11.0     2009-11.0-1151     2009-11.0-1441  215.0  179.0
# 113964     14.0     2021-14.0-1429     2021-14.0-1201   55.0  186.0
# 16414      11.0     2005-11.0-1264     2005-11.0-1310  158.0  119.0
#
# [5 rows x 41 columns]

# %%
# Getting ranking differential to use as a variable - negative values are underdog wins
results_df['rank_diff'] = results_df['lrank'] - results_df['wrank']

# Getting Score differential just in case
results_df['spread'] = results_df['wscore'] - results_df['lscore']

# Outcome column for if the lower teamID won, as that is the submission format for Kaggle
results_df['lowidwin'] = np.where((results_df['wteamid'] < results_df['lteamid']), 1, 0)

results_df.sample(5)
# Out:
#        season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 41686    2009      61     1398      69     1184      63    H      0    27
# 1279     2003      54     1113      75     1304      63    H      0    28
# 34518    2008      63     1399      73     1287      55    H      0    24
# 258      2003      22     1166      80     1323      75    N      0    31
# 39571    2009      25     1216      50     1312      38    N      0    15
#
#        wfga  ...  wseason-Day-Team  lseason-Day-Team  weeknum  \
# 41686    49  ...      2009-61-1398      2009-61-1184      9.0
# 1279     61  ...      2003-54-1113      2003-54-1304      8.0
# 34518    50  ...      2008-63-1399      2008-63-1287      9.0
# 258      50  ...      2003-22-1166      2003-22-1323      4.0
# 39571    42  ...      2009-25-1216      2009-25-1312      4.0
#
#        wseason-week-team  lseason-week-team  wrank  lrank  rank_diff  spread  \
# 41686      2009-9.0-1398      2009-9.0-1184  280.0  131.0     -149.0       6
# 1279       2003-8.0-1113      2003-8.0-1304   56.0   59.0        3.0      12
# 34518      2008-9.0-1399      2008-9.0-1287  298.0  290.0       -8.0      18
# 258        2003-4.0-1166      2003-4.0-1323    NaN    NaN        NaN       5
# 39571      2009-4.0-1216      2009-4.0-1312  306.0  345.0       39.0      12
#
#        lowidwin
# 41686         0
# 1279          1
# 34518         0
# 258           1
# 39571         1
#
# [5 rows x 44 columns]

# %%
results_df.columns
# Out:
# Index(['season', 'daynum', 'wteamid', 'wscore', 'lteamid', 'lscore', 'wloc',
#        'numot', 'wfgm', 'wfga', 'wfgm3', 'wfga3', 'wftm', 'wfta', 'wor', 'wdr',
#        'wast', 'wto', 'wstl', 'wblk', 'wpf', 'lfgm', 'lfga', 'lfgm3', 'lfga3',
#        'lftm', 'lfta', 'lor', 'ldr', 'last', 'lto', 'lstl', 'lblk', 'lpf',
#        'wseason-Day-Team', 'lseason-Day-Team', 'weeknum', 'wseason-week-team',
#        'lseason-week-team', 'wrank', 'lrank', 'rank_diff', 'spread',
#        'lowidwin'],
#       dtype='object')

# %%
# Getting shooting percentages

results_df['wfgpct'] = results_df['wfgm'] / results_df['wfga']
results_df['lfgpct'] = results_df['lfgm'] / results_df['lfga']

results_df['wfg3pct'] = results_df['wfgm3'] / results_df['wfga3']
results_df['lfg3pct'] = results_df['lfgm3'] / results_df['lfga3']

results_df['wefgpct'] = (results_df['wfgm'] + 0.5 * results_df['wfga3']) / results_df['wfga']
results_df['lefgpct'] = (results_df['lfgm'] + 0.5 * results_df['lfgm3']) / results_df['lfga']

results_df['wftpct'] = results_df['wftm'] / results_df['wfta']
results_df['lftpct'] = results_df['lftm'] / results_df['lfta']

results_df.sample(5)
# Out:
#         season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  \
# 69147     2013     108     1149      92     1440      69    H      0    35
# 39516     2009      23     1135      80     1119      73    H      0    26
# 48889     2010      39     1269      81     1212      58    H      0    32
# 22405     2006      91     1105      99     1411      75    H      0    33
# 115894    2021     132     1159      85     1259      72    H      0    31
#
#         wfga  ...  spread  lowidwin    wfgpct    lfgpct   wfg3pct   lfg3pct  \
# 69147     59  ...      23         1  0.593220  0.393939  0.560000  0.314286
# 39516     48  ...       7         0  0.541667  0.483333  0.500000  0.352941
# 48889     70  ...      23         0  0.457143  0.406250  0.181818  0.200000
# 22405     68  ...      24         1  0.485294  0.461538  0.440000  0.444444
# 115894    59  ...      13         1  0.525424  0.467742  0.608696  0.227273
#
#          wefgpct   lefgpct    wftpct  lftpct
# 69147   0.805085  0.477273  0.533333  0.7500
# 39516   0.750000  0.533333  0.692308  0.6000
# 48889   0.614286  0.437500  0.619048  0.2000
# 22405   0.669118  0.538462  0.594595  0.4750
# 115894  0.720339  0.508065  0.642857  0.5625
#
# [5 rows x 52 columns]

# %%
# getting differentials between teams for stats

results_df['fgpct_diff'] = results_df['wfgpct'] - results_df['lfgpct']
results_df['fg3pct_diff'] = results_df['wfg3pct'] - results_df['lfg3pct']
results_df['efgpct_diff'] = results_df['wefgpct'] - results_df['lefgpct']
results_df['ftpct_diff'] = results_df['wftpct'] - results_df['lftpct']
results_df['or_diff'] = results_df['wor'] - results_df['lor']
results_df['dr_diff'] = results_df['wdr'] - results_df['ldr']
results_df['ast_diff'] = results_df['wast'] - results_df['last']
results_df['to_diff'] = results_df['wto'] - results_df['lto']
results_df['stl_diff'] = results_df['wstl'] - results_df['lstl']
results_df['blk_diff'] = results_df['wblk'] - results_df['lblk']
results_df['pf_diff'] = results_df['wpf'] - results_df['lpf']

results_df.columns
# Out:
# Index(['season', 'daynum', 'wteamid', 'wscore', 'lteamid', 'lscore', 'wloc',
#        'numot', 'wfgm', 'wfga', 'wfgm3', 'wfga3', 'wftm', 'wfta', 'wor', 'wdr',
#        'wast', 'wto', 'wstl', 'wblk', 'wpf', 'lfgm', 'lfga', 'lfgm3', 'lfga3',
#        'lftm', 'lfta', 'lor', 'ldr', 'last', 'lto', 'lstl', 'lblk', 'lpf',
#        'wseason-Day-Team', 'lseason-Day-Team', 'weeknum', 'wseason-week-team',
#        'lseason-week-team', 'wrank', 'lrank', 'rank_diff', 'spread',
#        'lowidwin', 'wfgpct', 'lfgpct', 'wfg3pct', 'lfg3pct', 'wefgpct',
#        'lefgpct', 'wftpct', 'lftpct', 'fgpct_diff', 'fg3pct_diff',
#        'efgpct_diff', 'ftpct_diff', 'or_diff', 'dr_diff', 'ast_diff',
#        'to_diff', 'stl_diff', 'blk_diff', 'pf_diff'],
#       dtype='object')

# %%
# Drop NA's for a nice and pretty DF

clean_results_df = results_df.dropna()

clean_results_df.head()
# Out:
#      season  daynum  wteamid  wscore  lteamid  lscore wloc  numot  wfgm  wfga  \
# 792    2003      36     1113      76     1305      63    H      0    25    57
# 793    2003      36     1116      72     1256      60    H      0    25    58
# 794    2003      36     1130      85     1235      78    A      0    28    57
# 795    2003      36     1139      75     1133      70    H      0    23    56
# 796    2003      36     1143      67     1364      60    H      0    18    42
#
#      ...  fg3pct_diff  efgpct_diff  ftpct_diff  or_diff  dr_diff  ast_diff  \
# 792  ...     0.031579     0.025560    0.323810       -4        4         2
# 793  ...     0.038363     0.169310   -0.117794        1       -2         4
# 794  ...     0.052632     0.224071   -0.053350      -10        0        -1
# 795  ...    -0.478469     0.019133    0.235577        4       -1        -5
# 796  ...     0.076923     0.052857    0.233333        4        2        -8
#
#      to_diff  stl_diff  blk_diff  pf_diff
# 792       -8         3        -1       -7
# 793       -7        -1         0       -1
# 794       -1         3        -5        3
# 795       -4         3         0       -4
# 796       -1         2         1      -16
#
# [5 rows x 63 columns]

# %% [markdown]
# # Model Assembly and Training

# %%
# X = ranks, y = win?

y = clean_results_df['lowidwin']
X = clean_results_df[['rank_diff', 'efgpct_diff', 'ftpct_diff', 'or_diff', 'dr_diff',
       'ast_diff', 'to_diff', 'stl_diff', 'blk_diff', 'pf_diff']]

# %%
# Do TTS 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (82959, 10)

# %%
# Set up the Balanced Random Forest

from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=250, random_state=1)
brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=250, random_state=1)

# %%
prob_predictions = brf.predict_proba(X_test)
print (prob_predictions)
# Out:
# [[0.892 0.108]
#  [0.66  0.34 ]
#  [0.388 0.612]
#  ...
#  [0.356 0.644]
#  [0.936 0.064]
#  [0.388 0.612]]

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.620705865335937

# %%
# Get importances and features
importances = brf.feature_importances_
cols = X.columns

# Store in a DataFrame
feature_importances_df = pd.DataFrame({'feature':cols, 'importance': importances})
feature_importances_df
# Out:
#        feature  importance
# 0    rank_diff    0.126650
# 1  efgpct_diff    0.146385
# 2   ftpct_diff    0.145825
# 3      or_diff    0.089197
# 4      dr_diff    0.082253
# 5     ast_diff    0.088167
# 6      to_diff    0.082906
# 7     stl_diff    0.076741
# 8     blk_diff    0.078299
# 9      pf_diff    0.083577

# %% [markdown]
# # Generating 2022 bracket predictions

# %%
# Now we need to get these predictions for all tournament games

# 1. Get season averages for teams meeting in the tournament GROUP BY WHERE SEASON = 2022, Get 64 tourney teams
# 2. Calculate the differentials to use as inputs for predictions for all potential matchups

# %% [markdown]
# ## Getting season average stats by team

# %%
# Getting Team stats for a season (uses clean_results so may exclude a few games bc of rankings)

# Grab results for a team where it was the winner
w_teams = clean_results_df.loc[:, ['season', 'wteamid', 'wfgm','wfga','wfgm3',
                                   'wfga3','wftm', 'wfta', 'wor', 'wdr','wast', 
                                   'wto', 'wstl', 'wblk', 'wpf']]

w_teams.columns = ['Season', 'TeamID', 'FGM','FGA','FGM3','FGA3','FTM','FTA','OR','DR',
             'Ast','TO','Stl','Blk','PF']

# Grab results for a team where it was the loser
l_teams = clean_results_df.loc[:, ['season', 'lteamid', 'lfgm', 'lfga', 'lfgm3',
                                   'lfga3','lftm', 'lfta', 'lor', 'ldr', 'last',
                                   'lto', 'lstl', 'lblk', 'lpf']]

l_teams.columns = ['Season', 'TeamID', 'FGM','FGA','FGM3','FGA3','FTM','FTA','OR','DR',
             'Ast','TO','Stl','Blk','PF']

# Merge those together then get shooting effeciency
detail = pd.concat([w_teams,l_teams])
detail['FGPct'] = detail.FGM / detail.FGA 
detail['FG3Pct'] = detail.FGM3 / detail.FGA3  
detail['eFGPct'] = (detail.FGM + 0.5 * detail.FGM3)/detail.FGA
detail['FTPct'] = detail.FTM  / detail.FTA  

# Bring it together by Season and Team
team_stats = detail.groupby(['Season','TeamID'])['FGM','FGA','FGM3','FGA3','FTM','FTA',
                                         'OR','DR','Ast','TO','Stl','Blk','PF',
                                          'FGPct', 'FG3Pct', 
                                         'eFGPct', 'FTPct']\
                                        .mean().fillna(0).reset_index()

del w_teams, l_teams, detail

team_stats.sample(5)
# Out:
# /Users/shane/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#       Season  TeamID        FGM        FGA       FGM3       FGA3        FTM  \
# 5562    2019    1189  25.107143  57.642857  10.071429  28.857143   9.250000
# 2152    2009    1269  24.450000  60.800000   8.000000  25.525000   9.925000
# 1445    2007    1243  23.741935  53.612903   6.548387  18.645161  15.709677
# 6444    2021    1379  23.440000  55.120000   4.920000  16.200000  10.440000
# 4062    2014    1451  24.060606  49.575758   7.575758  18.818182  17.121212
#
#             FTA         OR         DR        Ast         TO       Stl  \
# 5562  13.250000   7.750000  24.785714  14.107143  12.285714  4.107143
# 2152  14.525000  11.125000  24.000000  13.400000  13.275000  6.475000
# 1445  22.451613  12.000000  22.387097  15.290323  14.225806  6.064516
# 6444  14.760000   6.080000  24.560000  12.600000  13.720000  6.000000
# 4062  22.818182   8.030303  24.878788  13.484848  11.848485  3.545455
#
#            Blk         PF     FGPct    FG3Pct    eFGPct     FTPct
# 5562  1.821429  16.785714  0.435897  0.348486  0.523465  0.715140
# 2152  5.175000  17.000000  0.403739  0.314841  0.470400  0.668998
# 1445  3.258065  17.903226  0.443342  0.347726  0.504838  0.684200
# 6444  2.440000   4.400000  0.426644  0.291976  0.471588  0.691492
# 4062  3.333333  17.727273  0.486463  0.401983  0.563788  0.752104

# %%
# Get just 2022 and then add rankings for final week

teams_2022 = team_stats[team_stats.Season == 2022]
teams_2022.sample(5)
# Out:
#       Season  TeamID        FGM        FGA      FGM3       FGA3        FTM  \
# 6737    2022    1314  27.380952  61.523810  8.428571  21.904762  13.857143
# 6630    2022    1204  23.375000  54.187500  5.375000  19.187500  10.875000
# 6621    2022    1195  26.571429  60.047619  9.904762  28.761905  11.904762
# 6546    2022    1115  21.315789  52.631579  5.526316  20.315789  12.105263
# 6545    2022    1114  22.187500  55.000000  6.812500  21.187500  14.000000
#
#             FTA        OR         DR        Ast         TO       Stl  \
# 6737  18.047619  9.571429  28.428571  14.333333  11.523810  5.142857
# 6630  16.562500  8.812500  23.125000  10.937500  14.812500  6.562500
# 6621  17.333333  9.666667  24.333333  15.571429  13.523810  6.857143
# 6546  17.947368  6.684211  18.473684  11.052632  13.947368  6.263158
# 6545  18.750000  7.062500  20.187500  12.687500  13.000000  6.187500
#
#            Blk         PF     FGPct    FG3Pct    eFGPct     FTPct
# 6737  3.714286  14.571429  0.446994  0.384497  0.515554  0.758335
# 6630  2.875000  18.812500  0.431772  0.284029  0.481661  0.664786
# 6621  4.761905  13.952381  0.441124  0.344554  0.523871  0.680863
# 6546  2.736842  17.052632  0.402026  0.270616  0.455055  0.668017
# 6545  2.312500  17.500000  0.401928  0.318036  0.462877  0.725596

# %%
# Find last week of the season for rankings in 2022

SAG2022_ranks = SAG_ranks[SAG_ranks['season']==2022]
SAG2022_ranks['rankingweek'].max()
# Out:
# 15.0

# %%
# Getting 2022 season-end rankings

end_ranks = SAG_ranks[SAG_ranks.rankingweek == 15]
end_ranks_2022 = end_ranks[end_ranks.season == 2022]
end_ranks_2022.head()
# Out:
#          season  rankingdaynum systemname  teamid  ordinalrank  \
# 3318459    2022            100        SAG    1101          151
# 3318460    2022            100        SAG    1102          254
# 3318461    2022            100        SAG    1103          131
# 3318462    2022            100        SAG    1104           19
# 3318463    2022            100        SAG    1105          348
#
#         season-day-team  rankingweek season-week-team
# 3318459   2022-100-1101         15.0   2022-15.0-1101
# 3318460   2022-100-1102         15.0   2022-15.0-1102
# 3318461   2022-100-1103         15.0   2022-15.0-1103
# 3318462   2022-100-1104         15.0   2022-15.0-1104
# 3318463   2022-100-1105         15.0   2022-15.0-1105

# %%
# Adding the 2022-end rankings into teams_2022

teams_2022 = teams_2022.merge(end_ranks_2022[['teamid','ordinalrank']], how='left', left_on='TeamID', right_on='teamid').drop(['teamid'], axis=1)
teams_2022.rename(columns={'ordinalrank': 'end_rank'},inplace=True)

teams_2022.head()
# Out:
#    Season  TeamID        FGM        FGA      FGM3       FGA3        FTM  \
# 0    2022    1101  25.058824  59.058824  6.882353  21.352941  17.176471
# 1    2022    1102  21.842105  49.263158  7.842105  21.894737   8.842105
# 2    2022    1103  23.555556  53.000000  7.833333  22.500000  13.777778
# 3    2022    1104  27.142857  62.428571  8.666667  29.047619  15.523810
# 4    2022    1105  21.263158  56.578947  3.736842  14.315789  11.000000
#
#          FTA         OR         DR        Ast         TO        Stl       Blk  \
# 0  23.235294   8.588235  20.352941  13.941176  12.352941  10.294118  1.529412
# 1  13.631579   5.105263  19.736842  13.210526  11.631579   6.263158  3.263158
# 2  20.611111   8.000000  24.055556  12.000000  11.166667   5.000000  2.777778
# 3  21.619048  11.666667  24.285714  13.714286  13.523810   7.285714  5.095238
# 4  16.157895   8.736842  21.736842   9.421053  14.263158   8.315789  3.052632
#
#           PF     FGPct    FG3Pct    eFGPct     FTPct  end_rank
# 0  22.647059  0.424027  0.318485  0.482021  0.739285       151
# 1  18.473684  0.446294  0.357070  0.525694  0.639186       254
# 2  15.944444  0.445353  0.352604  0.520504  0.650718       131
# 3  18.523810  0.437620  0.300061  0.506297  0.709938        19
# 4  16.842105  0.379589  0.264676  0.412969  0.687256       348

# %% [markdown]
# ## Readying a submission file

# %%
# Get submission file
sub_df = pd.read_csv('Resources/MSampleSubmissionStage2.csv').drop(['Pred'],axis=1)
sub_df['Season'] = sub_df['ID'].map(lambda x: int(x.split('_')[0]))
sub_df['TeamA'] = sub_df['ID'].map(lambda x: int(x.split('_')[1]))
sub_df['TeamB'] = sub_df['ID'].map(lambda x: int(x.split('_')[2]))

sub_df.head()
# Out:
#                ID  Season  TeamA  TeamB
# 0  2022_1103_1104    2022   1103   1104
# 1  2022_1103_1112    2022   1103   1112
# 2  2022_1103_1116    2022   1103   1116
# 3  2022_1103_1120    2022   1103   1120
# 4  2022_1103_1124    2022   1103   1124

# %%
# Team A & B Lists

team_A = pd.DataFrame(sub_df[['ID','TeamA']].copy())
team_B = pd.DataFrame(sub_df[['ID','TeamB']].copy())

# %%
# Get Team A stats

merge_cols = ['TeamID', 'FGM','FGA','FGM3','FGA3','FTM','FTA','OR','DR',
             'Ast','TO','Stl','Blk','PF', 'end_rank']

team_A = team_A.merge(teams_2022[merge_cols], how='left', left_on='TeamA', right_on='TeamID').drop(['TeamID'], axis=1)

print(team_A.shape)
team_A.sample(5)
# Out:
# (2278, 16)
#                   ID  TeamA        FGM        FGA      FGM3       FGA3  \
# 72    2022_1104_1136   1104  27.142857  62.428571  8.666667  29.047619
# 1209  2022_1231_1277   1231  26.500000  56.250000  6.400000  17.800000
# 1523  2022_1260_1397   1260  25.263158  53.052632  8.421053  22.526316
# 1342  2022_1240_1286   1240  25.052632  54.947368  9.000000  23.000000
# 939   2022_1174_1400   1174  26.350000  55.850000  8.000000  22.650000
#
#             FTM        FTA         OR         DR        Ast         TO  \
# 72    15.523810  21.619048  11.666667  24.285714  13.714286  13.523810
# 1209  13.200000  19.250000   8.000000  25.950000  15.000000  12.550000
# 1523  12.421053  16.894737   5.894737  23.368421  13.736842  11.052632
# 1342  13.210526  19.947368   8.526316  25.684211  13.263158  12.421053
# 939   13.600000  18.150000   7.450000  22.550000  13.600000  12.600000
#
#            Stl       Blk         PF  end_rank
# 72    7.285714  5.095238  18.523810        19
# 1209  6.050000  5.250000  16.750000        27
# 1523  5.947368  2.684211  16.105263        35
# 1342  6.157895  2.789474  14.894737       143
# 939   6.050000  3.650000  15.750000       155

# %%
# Get shooting percentages and rename columns

team_A['FGPct'] = team_A.FGM / team_A.FGA 
team_A['FG3Pct'] = team_A.FGM3 / team_A.FGA3  
team_A['eFGPct'] = (team_A.FGM + 0.5 * team_A.FGM3)/team_A.FGA
team_A['FTPct'] = team_A.FTM  / team_A.FTA  

# Rename to be A_''
team_A.columns = ['ID','TeamA', 'A_FGM','A_FGA','A_FGM3','A_FGA3','A_FTM','A_FTA','A_OR','A_DR',
             'A_Ast','A_TO','A_Stl','A_Blk','A_PF', 'A_rank', 'A_FGPct', 'A_FG3Pct', 'A_eFGPct','A_FTPct']

print(team_A.shape)
team_A.sample(5)
# Out:
# (2278, 20)
#                   ID  TeamA      A_FGM      A_FGA    A_FGM3     A_FGA3  \
# 1489  2022_1255_1417   1255  25.764706  57.294118  7.941176  21.588235
# 274   2022_1120_1209   1120  28.571429  63.666667  8.142857  25.190476
# 822   2022_1168_1345   1168  23.437500  55.250000  5.437500  16.937500
# 1250  2022_1234_1266   1234  28.750000  64.550000  8.300000  24.900000
# 1070  2022_1211_1293   1211  33.777778  63.444444  9.111111  23.666667
#
#           A_FTM      A_FTA       A_OR       A_DR      A_Ast       A_TO  \
# 1489  14.176471  19.764706   9.470588  22.941176  13.000000  11.764706
# 274   14.619048  19.714286  10.095238  25.476190  14.571429  11.238095
# 822   16.562500  21.000000   8.187500  22.937500   9.562500  11.500000
# 1250  14.900000  19.700000  10.800000  22.750000  15.500000   8.500000
# 1070  14.500000  20.555556   9.055556  31.222222  18.722222  12.000000
#
#          A_Stl     A_Blk       A_PF  A_rank   A_FGPct  A_FG3Pct  A_eFGPct  \
# 1489  7.647059  2.235294  16.529412     191  0.449692  0.367847  0.518994
# 274   8.904762  7.952381  18.095238       9  0.448766  0.323251  0.512715
# 822   6.875000  2.125000  16.562500     164  0.424208  0.321033  0.473416
# 1250  7.950000  4.450000  16.350000      21  0.445391  0.333333  0.509682
# 1070  7.055556  5.722222  16.000000       1  0.532399  0.384977  0.604203
#
#        A_FTPct
# 1489  0.717262
# 274   0.741546
# 822   0.788690
# 1250  0.756345
# 1070  0.705405

# %%
# Team B Stats

merge_cols = ['TeamID', 'FGM','FGA','FGM3','FGA3','FTM','FTA','OR','DR',
             'Ast','TO','Stl','Blk','PF', 'end_rank']

# Rename to be B_''
team_B = team_B.merge(teams_2022[merge_cols], how='left', left_on='TeamB', right_on='TeamID').drop(['TeamID'], axis=1)

print(team_B.shape)
team_B.sample(5)
# Out:
# (2278, 16)
#                   ID  TeamB        FGM        FGA      FGM3       FGA3  \
# 442   2022_1129_1437   1437  24.476190  56.047619  8.952381  25.428571
# 1113  2022_1222_1272   1272  27.166667  58.555556  6.166667  18.000000
# 119   2022_1104_1397   1397  26.250000  60.200000  8.700000  26.150000
# 1659  2022_1274_1350   1350  26.318182  58.454545  8.545455  25.363636
# 1085  2022_1211_1389   1389  23.062500  54.750000  6.187500  17.000000
#
#             FTM        FTA         OR         DR        Ast         TO  \
# 442   14.095238  16.857143   9.000000  23.238095  12.285714   9.142857
# 1113  14.888889  22.500000  11.166667  23.944444  15.722222  16.055556
# 119   11.600000  16.750000   9.950000  23.000000  16.850000  12.300000
# 1659  11.863636  16.590909   6.636364  23.818182  15.681818   9.363636
# 1085  15.250000  21.437500   9.125000  23.187500  13.000000  13.187500
#
#            Stl       Blk         PF  end_rank
# 442   6.000000  2.380952  15.285714        10
# 1113  8.444444  5.444444  19.277778        42
# 119   9.650000  4.300000  16.900000        13
# 1659  8.409091  2.227273  13.636364        77
# 1085  8.000000  4.562500  19.562500       173

# %%
# Get shooting percentages and rename columns

team_B['FGPct'] = team_B.FGM / team_B.FGA 
team_B['FG3Pct'] = team_B.FGM3 / team_B.FGA3  
team_B['eFGPct'] = (team_B.FGM + 0.5 * team_B.FGM3)/team_B.FGA
team_B['FTPct'] = team_B.FTM  / team_B.FTA  

team_B.columns = ['ID','TeamB', 'B_FGM','B_FGA','B_FGM3','B_FGA3','B_FTM','B_FTA','B_OR','B_DR',
             'B_Ast','B_TO','B_Stl','B_Blk','B_PF', 'B_rank', 'B_FGPct', 'B_FG3Pct', 'B_eFGPct','B_FTPct']

print(team_B.shape)
team_B.sample(5)
# Out:
# (2278, 20)
#                   ID  TeamB      B_FGM      B_FGA    B_FGM3     B_FGA3  \
# 1619  2022_1272_1314   1314  27.380952  61.523810  8.428571  21.904762
# 1370  2022_1240_1439   1439  25.800000  54.350000  9.350000  22.400000
# 1457  2022_1246_1463   1463  25.388889  58.444444  7.388889  21.888889
# 1284  2022_1234_1458   1458  25.210526  59.473684  7.052632  21.894737
# 1755  2022_1286_1326   1326  26.187500  54.687500  8.687500  23.312500
#
#           B_FTM      B_FTA      B_OR       B_DR      B_Ast       B_TO  \
# 1619  13.857143  18.047619  9.571429  28.428571  14.333333  11.523810
# 1370   9.350000  12.700000  7.650000  21.300000  14.500000  10.850000
# 1457  14.444444  19.500000  7.888889  25.500000  12.444444  12.833333
# 1284  13.842105  18.526316  7.789474  24.105263  11.578947   8.105263
# 1755  13.750000  18.000000  7.625000  25.500000  14.437500  11.312500
#
#          B_Stl     B_Blk       B_PF  B_rank   B_FGPct  B_FG3Pct  B_eFGPct  \
# 1619  5.142857  3.714286  14.571429      33  0.445046  0.384783  0.513545
# 1370  5.050000  3.050000  15.000000      38  0.474701  0.417411  0.560718
# 1457  5.722222  3.166667  19.000000     132  0.434411  0.337563  0.497624
# 1284  4.842105  2.631579  16.947368      24  0.423894  0.322115  0.483186
# 1755  4.500000  4.687500  16.687500      17  0.478857  0.372654  0.558286
#
#        B_FTPct
# 1619  0.767810
# 1370  0.736220
# 1457  0.740741
# 1284  0.747159
# 1755  0.763889

# %%
# Reminder of features, so we know what columns to keep for the merge and in what order

# 'rank_diff', 'efgpct_diff', 'ftpct_diff', 'or_diff', 'dr_diff',
#        'ast_diff', 'to_diff', 'stl_diff', 'blk_diff', 'pf_diff'

print(feature_importances_df['feature'])
# Out:
# 0      rank_diff
# 1    efgpct_diff
# 2     ftpct_diff
# 3        or_diff
# 4        dr_diff
# 5       ast_diff
# 6        to_diff
# 7       stl_diff
# 8       blk_diff
# 9        pf_diff
# Name: feature, dtype: object

# %%
# Merge these two stat tables, so we can take the differences and run our model
team_AB = pd.DataFrame(sub_df['ID'].copy())

# Merge with team_A

merge_A = ['ID','TeamA','A_rank','A_eFGPct', 'A_FTPct', 'A_OR','A_DR','A_Ast','A_TO','A_Stl','A_Blk','A_PF']

team_AB = team_AB.merge(team_A[merge_A], how='left', left_on='ID', right_on='ID')
# Merge with team_B

merge_B = ['ID','TeamB','B_rank','B_eFGPct', 'B_FTPct', 'B_OR','B_DR','B_Ast','B_TO','B_Stl','B_Blk','B_PF']

team_AB = team_AB.merge(team_B[merge_B], how='left', left_on='ID', right_on='ID')

# Check the new team_AB. This contains all potential March Madness 2022 matchups, 
# and the teams' average stats and ending rank

team_AB.head()
# Out:
#                ID  TeamA  A_rank  A_eFGPct   A_FTPct  A_OR       A_DR  A_Ast  \
# 0  2022_1103_1104   1103     131  0.518344  0.668464   8.0  24.055556   12.0
# 1  2022_1103_1112   1103     131  0.518344  0.668464   8.0  24.055556   12.0
# 2  2022_1103_1116   1103     131  0.518344  0.668464   8.0  24.055556   12.0
# 3  2022_1103_1120   1103     131  0.518344  0.668464   8.0  24.055556   12.0
# 4  2022_1103_1124   1103     131  0.518344  0.668464   8.0  24.055556   12.0
#
#         A_TO  A_Stl  ...  B_rank  B_eFGPct   B_FTPct       B_OR       B_DR  \
# 0  11.166667    5.0  ...      19  0.504195  0.718062  11.666667  24.285714
# 1  11.166667    5.0  ...       2  0.542520  0.725995  11.600000  28.800000
# 2  11.166667    5.0  ...      22  0.502342  0.742268   9.666667  25.904762
# 3  11.166667    5.0  ...       9  0.512715  0.741546  10.095238  25.476190
# 4  11.166667    5.0  ...       7  0.537773  0.677233  11.285714  22.238095
#
#        B_Ast       B_TO     B_Stl     B_Blk       B_PF
# 0  13.714286  13.523810  7.285714  5.095238  18.523810
# 1  19.600000  13.600000  6.650000  6.200000  16.450000
# 2  14.904762  12.380952  8.095238  4.476190  17.190476
# 3  14.571429  11.238095  8.904762  7.952381  18.095238
# 4  15.904762  12.571429  9.761905  3.095238  15.714286
#
# [5 rows x 23 columns]

# %%
# Now, take differentials (A-B) so it aligns with our model features

team_AB_diffs = pd.DataFrame(team_AB[['ID','TeamA','TeamB']]).copy()

# 'rank_diff', 'efgpct_diff', 'ftpct_diff', 'or_diff', 'dr_diff',
#        'ast_diff', 'to_diff', 'stl_diff', 'blk_diff', 'pf_diff'

team_AB_diffs['rank_diff'] = team_AB['A_rank'] - team_AB['B_rank']
team_AB_diffs['efgpct_diff'] = team_AB['A_eFGPct'] - team_AB['B_eFGPct']
team_AB_diffs['ftpct_diff'] = team_AB['A_FTPct'] - team_AB['B_FTPct']
team_AB_diffs['or_diff'] = team_AB['A_OR'] - team_AB['B_OR']
team_AB_diffs['dr_diff'] = team_AB['A_DR'] - team_AB['B_DR']
team_AB_diffs['ast_diff'] = team_AB['A_Ast'] - team_AB['B_Ast']
team_AB_diffs['to_diff'] = team_AB['A_TO'] - team_AB['B_TO']
team_AB_diffs['stl_diff'] = team_AB['A_Stl'] - team_AB['B_Stl']
team_AB_diffs['blk_diff'] = team_AB['A_Blk'] - team_AB['B_Blk']
team_AB_diffs['pf_diff'] = team_AB['A_PF'] - team_AB['B_PF']
team_AB_diffs['lowIDwin'] = ""

team_AB_diffs.head()
# Out:
#                ID  TeamA  TeamB  rank_diff  efgpct_diff  ftpct_diff   or_diff  \
# 0  2022_1103_1104   1103   1104        112     0.014149   -0.049598 -3.666667
# 1  2022_1103_1112   1103   1112        129    -0.024176   -0.057532 -3.600000
# 2  2022_1103_1116   1103   1116        109     0.016002   -0.073804 -1.666667
# 3  2022_1103_1120   1103   1120        122     0.005629   -0.073082 -2.095238
# 4  2022_1103_1124   1103   1124        124    -0.019429   -0.008770 -3.285714
#
#     dr_diff  ast_diff   to_diff  stl_diff  blk_diff   pf_diff lowIDwin
# 0 -0.230159 -1.714286 -2.357143 -2.285714 -2.317460 -2.579365
# 1 -4.744444 -7.600000 -2.433333 -1.650000 -3.422222 -0.505556
# 2 -1.849206 -2.904762 -1.214286 -3.095238 -1.698413 -1.246032
# 3 -1.420635 -2.571429 -0.071429 -3.904762 -5.174603 -2.150794
# 4  1.817460 -3.904762 -1.404762 -4.761905 -0.317460  0.230159

# %%
# Run the model
X_AB = team_AB_diffs[['rank_diff', 'efgpct_diff', 'ftpct_diff', 'or_diff', 'dr_diff',
       'ast_diff', 'to_diff', 'stl_diff', 'blk_diff', 'pf_diff']]

# %%
y_pred = brf.predict(X_AB)
print(y_pred)
# Out:
# [1 0 1 ... 0 1 0]

# %%
columns = ['lowidwin']

predictions_AB = pd.DataFrame(y_pred, index=team_AB_diffs.ID, columns=columns)
predictions_AB.head()
# Out:
#                 lowidwin
# ID
# 2022_1103_1104         1
# 2022_1103_1112         0
# 2022_1103_1116         1
# 2022_1103_1120         1
# 2022_1103_1124         0

# %%
y_probs = brf.predict_proba(X_AB)
print(y_probs)
# Out:
# [[0.408 0.592]
#  [0.504 0.496]
#  [0.452 0.548]
#  ...
#  [0.608 0.392]
#  [0.476 0.524]
#  [0.528 0.472]]

# %%
columns = ['lowidlose_prob','lowidwin_prob']

probs_AB = pd.DataFrame(y_probs, index=team_AB_diffs.ID, columns=columns)
probs_AB.head()
# Out:
#                 lowidlose_prob  lowidwin_prob
# ID
# 2022_1103_1104           0.408          0.592
# 2022_1103_1112           0.504          0.496
# 2022_1103_1116           0.452          0.548
# 2022_1103_1120           0.464          0.536
# 2022_1103_1124           0.512          0.488

# %%
# Test - GA State 1209 vs Gonzaga 1211. We definitely want to see lowidlose >0.6ish

test = probs_AB.loc[probs_AB.index=='2022_1209_1211']
test
# Out:
#                 lowidlose_prob  lowidwin_prob
# ID
# 2022_1209_1211           0.556          0.444

# %%
# Getting Team ID's and Team Names

probs_AB['LowIDwin'] = predictions_AB['lowidwin']
probs_AB['TeamA_ID'] = probs_AB.index.map(lambda x: int(x.split('_')[1]))
probs_AB['TeamB_ID'] = probs_AB.index.map(lambda x: int(x.split('_')[2]))


probs_AB.head()
# Out:
#                 lowidlose_prob  lowidwin_prob  LowIDwin  TeamA_ID  TeamB_ID
# ID
# 2022_1103_1104           0.408          0.592         1      1103      1104
# 2022_1103_1112           0.504          0.496         0      1103      1112
# 2022_1103_1116           0.452          0.548         1      1103      1116
# 2022_1103_1120           0.464          0.536         1      1103      1120
# 2022_1103_1124           0.512          0.488         0      1103      1124

# %%
teams_df
# Out:
#      teamid      teamname  firstd1season  lastd1season
# 0      1101   Abilene Chr           2014          2022
# 1      1102     Air Force           1985          2022
# 2      1103         Akron           1985          2022
# 3      1104       Alabama           1985          2022
# 4      1105   Alabama A&M           2000          2022
# ..      ...           ...            ...           ...
# 367    1468    Bellarmine           2021          2022
# 368    1469      Dixie St           2021          2022
# 369    1470   Tarleton St           2021          2022
# 370    1471  UC San Diego           2021          2022
# 371    1472  St Thomas MN           2022          2022
#
# [372 rows x 4 columns]

# %%
# Merge in Team names and make the bracket with this little cheat sheet!

# teams_2022 = teams_2022.merge(end_ranks_2022[['teamid','ordinalrank']], how='left', left_on='TeamID', right_on='teamid').drop(['teamid'], axis=1)

probs_AB = probs_AB.merge(teams_df[['teamid','teamname']], how='left', left_on='TeamA_ID', right_on='teamid').drop(['teamid'], axis=1)
probs_AB = probs_AB.merge(teams_df[['teamid','teamname']], how='left', left_on='TeamB_ID', right_on='teamid').drop(['teamid'], axis=1)

probs_AB.rename(columns={'teamname_x': 'TeamA_Name', 'teamname_y': 'TeamB_Name'},inplace=True)

probs_AB.head()
# Out:
#    lowidlose_prob  lowidwin_prob  LowIDwin  TeamA_ID  TeamB_ID TeamA_Name  \
# 0           0.408          0.592         1      1103      1104      Akron
# 1           0.504          0.496         0      1103      1112      Akron
# 2           0.452          0.548         1      1103      1116      Akron
# 3           0.464          0.536         1      1103      1120      Akron
# 4           0.512          0.488         0      1103      1124      Akron
#
#   TeamB_Name
# 0    Alabama
# 1    Arizona
# 2   Arkansas
# 3     Auburn
# 4     Baylor

# %%
probs_AB['Winner'] = np.where((probs_AB['LowIDwin'] ==1), probs_AB['TeamA_Name'], probs_AB['TeamB_Name'])
                              
probs_AB.head()
# Out:
#    lowidlose_prob  lowidwin_prob  LowIDwin  TeamA_ID  TeamB_ID TeamA_Name  \
# 0           0.408          0.592         1      1103      1104      Akron
# 1           0.504          0.496         0      1103      1112      Akron
# 2           0.452          0.548         1      1103      1116      Akron
# 3           0.464          0.536         1      1103      1120      Akron
# 4           0.512          0.488         0      1103      1124      Akron
#
#   TeamB_Name   Winner
# 0    Alabama    Akron
# 1    Arizona  Arizona
# 2   Arkansas    Akron
# 3     Auburn    Akron
# 4     Baylor   Baylor

# %%
# Export the model results as a csv

path = 'Exports/model_results.csv'

probs_AB.to_csv(path)

# %%
# 2022 Team Stats per game

path = 'Exports/team_stats_per_game.csv'

teams_2022.to_csv(path)
