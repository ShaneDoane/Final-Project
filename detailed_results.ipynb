# %%
# Importing Dependancies 
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Importing detailed results
detailed_results_df = pd.read_csv("../Resources/MNCAATourneyDetailedResults.csv")
detailed_results_df
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2003     134     1421      92     1411      84    N      1    32
# 1       2003     136     1112      80     1436      51    N      0    31
# 2       2003     136     1113      84     1272      71    N      0    31
# 3       2003     136     1141      79     1166      73    N      0    29
# 4       2003     136     1143      76     1301      74    N      1    27
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 1176    2021     148     1211      85     1425      66    N      0    33
# 1177    2021     148     1417      51     1276      49    N      0    21
# 1178    2021     152     1124      78     1222      59    N      0    29
# 1179    2021     152     1211      93     1417      90    N      1    37
# 1180    2021     154     1124      86     1211      70    N      0    30
#
#       WFGA  ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# ...

# %%
detailedcols = detailed_results_df.columns
detailedcols
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
detailed_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1181 entries, 0 to 1180
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   1181 non-null   int64
#  1   DayNum   1181 non-null   int64
#  2   WTeamID  1181 non-null   int64
#  3   WScore   1181 non-null   int64
#  4   LTeamID  1181 non-null   int64
#  5   LScore   1181 non-null   int64
#  6   WLoc     1181 non-null   object
#  7   NumOT    1181 non-null   int64
#  8   WFGM     1181 non-null   int64
#  9   WFGA     1181 non-null   int64
#  10  WFGM3    1181 non-null   int64
#  11  WFGA3    1181 non-null   int64
#  12  WFTM     1181 non-null   int64
#  13  WFTA     1181 non-null   int64
#  14  WOR      1181 non-null   int64
#  15  WDR      1181 non-null   int64
#  16  WAst     1181 non-null   int64
#  17  WTO      1181 non-null   int64
#  18  WStl     1181 non-null   int64
#  19  WBlk     1181 non-null   int64
#  20  WPF      1181 non-null   int64
# ...

# %%
detailed_results_df["WLoc"].value_counts()
# Out:
# N    1181
# Name: WLoc, dtype: int64

# %%
detailed_results_df.drop(columns= "WLoc", inplace = True)

# %%
detailed_results_df.corr()
# Out:
#            Season    DayNum   WTeamID    WScore   LTeamID    LScore     NumOT  \
# Season   1.000000  0.007896 -0.020088  0.020658 -0.007653 -0.002074 -0.034767
# DayNum   0.007896  1.000000 -0.074454 -0.004614  0.017832  0.083107  0.046160
# WTeamID -0.020088 -0.074454  1.000000 -0.025476 -0.046826 -0.016623  0.014690
# WScore   0.020658 -0.004614 -0.025476  1.000000 -0.086534  0.666268  0.159169
# LTeamID -0.007653  0.017832 -0.046826 -0.086534  1.000000 -0.025613  0.032580
# LScore  -0.002074  0.083107 -0.016623  0.666268 -0.025613  1.000000  0.323176
# NumOT   -0.034767  0.046160  0.014690  0.159169  0.032580  0.323176  1.000000
# WFGM     0.057977  0.006552 -0.048397  0.827359 -0.053405  0.468301  0.117713
# WFGA     0.079209  0.067700 -0.007732  0.485649 -0.041377  0.355603  0.261727
# WFGM3    0.107300 -0.004788  0.043837  0.383458 -0.024099  0.231553  0.076850
# WFGA3    0.190989 -0.002345  0.033444  0.191540 -0.021556  0.126510  0.138468
# ...

# %%
corrMatrix= detailed_results_df.corr()
sn.heatmap(corrMatrix,
          annot=True)
plt.figure
fig.set_size_inches(5, 5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ea9b81e87578> in <module>
#       2 sn.heatmap(corrMatrix,
#       3           annot=True)
# ----> 4 fig.set_size_inches(5, 5)
#       5 plt.show()
#
# NameError: name 'fig' is not defined

# %%
# importing ranking csv
rankings_df = pd.read_csv("../Resources/MMasseyOrdinals.csv")
rankings_df
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0          2003             35        SEL    1102          159
# 1          2003             35        SEL    1103          229
# 2          2003             35        SEL    1104           12
# 3          2003             35        SEL    1105          314
# 4          2003             35        SEL    1106          260
# ...         ...            ...        ...     ...          ...
# 4521715    2022            100        WOL    1468          183
# 4521716    2022            100        WOL    1469          259
# 4521717    2022            100        WOL    1470          209
# 4521718    2022            100        WOL    1471          270
# 4521719    2022            100        WOL    1472          296
#
# [4521720 rows x 5 columns]

# %%
# importing conferences csv
conferences_df = pd.read_csv("../Resources/MTeamConferences.csv")
conferences_df
# Out:
#        Season  TeamID ConfAbbrev
# 0        1985    1102        wac
# 1        1985    1103        ovc
# 2        1985    1104        sec
# 3        1985    1106       swac
# 4        1985    1108       swac
# ...       ...     ...        ...
# 12294    2022    1468      a_sun
# 12295    2022    1469        wac
# 12296    2022    1470        wac
# 12297    2022    1471   big_west
# 12298    2022    1472     summit
#
# [12299 rows x 3 columns]

# %%
# importing cities csv
teams_df = pd.read_csv("../Resources/MTeams.csv")
teams_df
# Out:
#      TeamID      TeamName  FirstD1Season  LastD1Season
# 0      1101   Abilene Chr           2014          2022
# 1      1102     Air Force           1985          2022
# 2      1103         Akron           1985          2022
# 3      1104       Alabama           1985          2022
# 4      1105   Alabama A&M           2000          2022
# ..      ...           ...            ...           ...
# 367    1468    Bellarmine           2021          2022
# 368    1469      Dixie St           2021          2022
# 369    1470   Tarleton St           2021          2022
# 370    1471  UC San Diego           2021          2022
# 371    1472  St Thomas MN           2022          2022
#
# [372 rows x 4 columns]

# %%
# Detailed Results are ready to go 
# Use to_sql()
