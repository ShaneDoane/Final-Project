# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Open the file
tourney_csv = "MNCAATourneyDetailedResults.csv"
tourney_df = pd.read_csv(tourney_csv)

tourney_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     31    14    31   17   28    16   15     5     0   22
# 1  ...     16     7     7    8   26    12   17    10     3   15
# 2  ...     28    14    21   20   22    11   12     2     5   18
# 3  ...     17    12    17   14   17    20   21     6     6   21
# 4  ...     21    15    20   10   26    16   14     5     8   19
#
# [5 rows x 34 columns]

# %%
# Add a column to designate tournament game
tourney_df['GameType'] = 'Tournament'

tourney_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF    GameType
# 0  ...    14    31   17   28    16   15     5     0   22  Tournament
# 1  ...     7     7    8   26    12   17    10     3   15  Tournament
# 2  ...    14    21   20   22    11   12     2     5   18  Tournament
# 3  ...    12    17   14   17    20   21     6     6   21  Tournament
# 4  ...    15    20   10   26    16   14     5     8   19  Tournament
#
# [5 rows x 35 columns]

# %%
# Import reg season results to make one df of all game records
# Open the file
reg_season_csv = "MRegularSeasonDetailedResults.csv"
reg_season_df = pd.read_csv(reg_season_csv)

reg_season_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     10    16    22   10   22     8   18     9     2   20
# 1  ...     24     9    20   20   25     7   12     8     6   16
# 2  ...     26    14    23   31   22     9   12     2     5   23
# 3  ...     22     8    15   17   20     9   19     4     3   23
# 4  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
# Add a column to designate regular season game
reg_season_df['GameType'] = 'RegSeason'

reg_season_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF   GameType
# 0  ...    16    22   10   22     8   18     9     2   20  RegSeason
# 1  ...     9    20   20   25     7   12     8     6   16  RegSeason
# 2  ...    14    23   31   22     9   12     2     5   23  RegSeason
# 3  ...     8    15   17   20     9   19     4     3   23  RegSeason
# 4  ...    17    27   21   15    12   10     7     1   14  RegSeason
#
# [5 rows x 35 columns]

# %%
# Get columns for concatenating the tables from the tourney df
tourney_df.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'GameType'],
#       dtype='object')

# %%
# Get columns for concatenating the tables from the reg season df
reg_season_df.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'GameType'],
#       dtype='object')

# %%
# Combine both tournament and reg season results
results_df = pd.concat([
        tourney_df[['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
       'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
       'GameType']],
        reg_season_df[['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
       'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
       'GameType']]
])

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF    GameType
# 0  ...    14    31   17   28    16   15     5     0   22  Tournament
# 1  ...     7     7    8   26    12   17    10     3   15  Tournament
# 2  ...    14    21   20   22    11   12     2     5   18  Tournament
# 3  ...    12    17   14   17    20   21     6     6   21  Tournament
# 4  ...    15    20   10   26    16   14     5     8   19  Tournament
#
# [5 rows x 35 columns]

# %%
# Confirm df lengths
print(len(tourney_df))
print(len(reg_season_df))
print(len(results_df))
# Out:
# 1181
# 100423
# 101604

# %%
# Import the ranking file
rank_csv = "MMasseyOrdinals.csv"
ranking_df = pd.read_csv(rank_csv)

ranking_df.head()
# Out:
#    Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0    2003             35        SEL    1102          159
# 1    2003             35        SEL    1103          229
# 2    2003             35        SEL    1104           12
# 3    2003             35        SEL    1105          314
# 4    2003             35        SEL    1106          260

# %%
# Narrow down to just the SAG ranks (based on Shane's research that they have the most ranks)
SAG_ranks = ranking_df.loc[ranking_df['SystemName']=='SAG']

SAG_ranks.head()
# Out:
#       Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 3622    2003             37        SAG    1102          114
# 3623    2003             37        SAG    1103          193
# 3624    2003             37        SAG    1104           11
# 3625    2003             37        SAG    1105          310
# 3626    2003             37        SAG    1106          257

# %%
# Add week number calculation for ranking and round up using numpy's ceiling function
SAG_ranks['WeekNum'] = (SAG_ranks['RankingDayNum']/7).apply(np.ceil)

SAG_ranks.head()
# Out:
# C:\Users\z002cr1\AppData\Local\Temp\1\ipykernel_32288\1465265135.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SAG_ranks['WeekNum'] = (SAG_ranks['RankingDayNum']/7).apply(np.ceil)
#       Season  RankingDayNum SystemName  TeamID  OrdinalRank  WeekNum
# 3622    2003             37        SAG    1102          114      6.0
# 3623    2003             37        SAG    1103          193      6.0
# 3624    2003             37        SAG    1104           11      6.0
# 3625    2003             37        SAG    1105          310      6.0
# 3626    2003             37        SAG    1106          257      6.0

# %%
# Add a Season-Week-Team column for merging with results df
SAG_ranks['Season-Week-Team'] = SAG_ranks['Season'].map(str) + '-' + SAG_ranks['WeekNum'].map(str) + '-' + SAG_ranks['TeamID'].map(str)

SAG_ranks.head()
# Out:
# C:\Users\z002cr1\AppData\Local\Temp\1\ipykernel_32288\1598262549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SAG_ranks['Season-Week-Team'] = SAG_ranks['Season'].map(str) + '-' + SAG_ranks['WeekNum'].map(str) + '-' + SAG_ranks['TeamID'].map(str)
#       Season  RankingDayNum SystemName  TeamID  OrdinalRank  WeekNum  \
# 3622    2003             37        SAG    1102          114      6.0
# 3623    2003             37        SAG    1103          193      6.0
# 3624    2003             37        SAG    1104           11      6.0
# 3625    2003             37        SAG    1105          310      6.0
# 3626    2003             37        SAG    1106          257      6.0
#
#      Season-Week-Team
# 3622    2003-6.0-1102
# 3623    2003-6.0-1103
# 3624    2003-6.0-1104
# 3625    2003-6.0-1105
# 3626    2003-6.0-1106

# %%
# Add week number to results df so we can eventually pull rank from SAG df
results_df['WeekNum'] = (results_df['DayNum']/7).apply(np.ceil)

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF    GameType  WeekNum
# 0  ...    31   17   28    16   15     5     0   22  Tournament     20.0
# 1  ...     7    8   26    12   17    10     3   15  Tournament     20.0
# 2  ...    21   20   22    11   12     2     5   18  Tournament     20.0
# 3  ...    17   14   17    20   21     6     6   21  Tournament     20.0
# 4  ...    20   10   26    16   14     5     8   19  Tournament     20.0
#
# [5 rows x 36 columns]

# %%
# Replace tournament NaN with most recent season rankings
results_df['WeekNum'].values[results_df['WeekNum'].values > 19.0] = 19.0
  
results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF    GameType  WeekNum
# 0  ...    31   17   28    16   15     5     0   22  Tournament     19.0
# 1  ...     7    8   26    12   17    10     3   15  Tournament     19.0
# 2  ...    21   20   22    11   12     2     5   18  Tournament     19.0
# 3  ...    17   14   17    20   21     6     6   21  Tournament     19.0
# 4  ...    20   10   26    16   14     5     8   19  Tournament     19.0
#
# [5 rows x 36 columns]

# %%
# Add a WSeason-Week-Team and LSeason_Week-Team column for merging with SAG df
results_df['WSeason-Week-Team'] = results_df['Season'].map(str) + '-' + results_df['WeekNum'].map(str) + '-' + results_df['WTeamID'].map(str)

results_df['LSeason-Week-Team'] = results_df['Season'].map(str) + '-' + results_df['WeekNum'].map(str) + '-' + results_df['LTeamID'].map(str)

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LDR  LAst  LTO  LStl  LBlk  LPF    GameType  WeekNum  \
# 0  ...   28    16   15     5     0   22  Tournament     19.0
# 1  ...   26    12   17    10     3   15  Tournament     19.0
# 2  ...   22    11   12     2     5   18  Tournament     19.0
# 3  ...   17    20   21     6     6   21  Tournament     19.0
# 4  ...   26    16   14     5     8   19  Tournament     19.0
#
#    WSeason-Week-Team  LSeason-Week-Team
# 0     2003-19.0-1421     2003-19.0-1411
# 1     2003-19.0-1112     2003-19.0-1436
# 2     2003-19.0-1113     2003-19.0-1272
# 3     2003-19.0-1141     2003-19.0-1166
# 4     2003-19.0-1143     2003-19.0-1301
#
# [5 rows x 38 columns]

# %%
# Merge rankings for winning team into the original results_df
results_df = results_df.merge(SAG_ranks[['Season-Week-Team','OrdinalRank']], how='left', left_on='WSeason-Week-Team', right_on='Season-Week-Team')

results_df.tail(50)
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 109144    2022      97     1103      71     1275      59    A      0    22
# 109145    2022      97     1145      77     1264      70    H      0    24
# 109146    2022      97     1156      84     1454      71    H      0    29
# 109147    2022      97     1222      80     1153      58    A      0    32
# 109148    2022      97     1234      71     1278      59    H      0    29
# 109149    2022      97     1236      71     1453      55    H      0    29
# 109150    2022      97     1260      71     1283      62    A      0    26
# 109151    2022      97     1284      76     1346      63    A      0    26
# 109152    2022      97     1310      80     1233      71    H      0    29
# 109153    2022      97     1326      82     1268      67    H      0    30
# 109154    2022      97     1344      71     1207      52    A      0    23
# 109155    2022      97     1361      65     1305      63    H      0    21
# 109156    2022      97     1373      62     1193      56    A      0    22
# 109157    2022      97     1389      66     1265      50    H      0    24
# 109158    2022      97     1390      87     1449      69    H      0    33
# 109159    2022      97     1461      61     1201      59    A      0    22
# 109160    2022      98     1108      79     1290      71    A      0    28
# 109161    2022      98     1112      91     1113      79    A      0    34
# 109162    2022      98     1125      72     1122      58    H      0    27
# 109163    2022      98     1150      81     1198      68    A      0    31
# 109164    2022      98     1151      74     1273      72    A      1    29
# 109165    2022      98     1159      87     1221      60    H      0    34
# 109166    2022      98     1180      72     1241      66    H      0    21
# 109167    2022      98     1190      75     1202      71    H      0    23
# 109168    2022      98     1197      61     1341      60    H      0    23
# 109169    2022      98     1212      58     1105      50    H      0    22
# 109170    2022      98     1214      74     1342      69    H      0    25
# 109171    2022      98     1220      73     1423      71    H      0    28
# 109172    2022      98     1224      69     1175      64    A      0    21
# 109173    2022      98     1238      60     1115      47    A      0    23
# 109174    2022      98     1262      85     1216      75    H      0    32
# 109175    2022      98     1285      78     1381      67    H      0    25
# 109176    2022      98     1286      72     1226      54    A      0    27
# 109177    2022      98     1292      84     1427      75    H      0    29
# 109178    2022      98     1294      82     1319      60    H      0    30
# 109179    2022      98     1295      76     1377      74    H      0    26
# 109180    2022      98     1298      68     1248      44    H      0    28
# 109181    2022      98     1306      67     1392      65    A      0    25
# 109182    2022      98     1317      66     1431      58    H      0    23
# 109183    2022      98     1350      62     1206      59    H      0    22
# 109184    2022      98     1354      74     1300      68    H      0    27
# 109185    2022      98     1369      76     1188      47    A      0    21
# 109186    2022      98     1378      52     1396      49    H      0    20
# 109187    2022      98     1380      72     1106      58    H      0    26
# 109188    2022      98     1399      84     1183      58    H      0    31
# 109189    2022      98     1400      79     1242      76    H      0    28
# 109190    2022      98     1411      66     1126      63    A      0    24
# 109191    2022      98     1422      68     1441      49    A      0    23
# 109192    2022      98     1438      69     1181      68    A      0    31
# 109193    2022      98     1439      74     1338      47    H      0    29
#
#         WFGA  ...  LTO  LStl  LBlk  LPF   GameType  WeekNum  \
# 109144    42  ...   10     8     1   19  RegSeason     14.0
# 109145    56  ...   15     6     3   25  RegSeason     14.0
# 109146    59  ...    7     2     3   18  RegSeason     14.0
# 109147    60  ...   10     6     3   12  RegSeason     14.0
# 109148    65  ...    9     4     4    9  RegSeason     14.0
# 109149    51  ...   11     5     1   13  RegSeason     14.0
# 109150    49  ...    9     4     2   12  RegSeason     14.0
# 109151    65  ...   17     7     3   23  RegSeason     14.0
# 109152    57  ...    9     4     3   16  RegSeason     14.0
# 109153    59  ...    9     5     0   13  RegSeason     14.0
# 109154    51  ...   16    11     4   16  RegSeason     14.0
# 109155    52  ...   14     4     4   22  RegSeason     14.0
# 109156    47  ...   10     8     2   14  RegSeason     14.0
# 109157    51  ...   14     8     8    8  RegSeason     14.0
# 109158    65  ...   11    10     5   14  RegSeason     14.0
# 109159    55  ...    2     4     3   15  RegSeason     14.0
# 109160    52  ...   13     8     3   20  RegSeason     14.0
# 109161    60  ...   13    12     4   21  RegSeason     14.0
# 109162    50  ...   13     3     2   11  RegSeason     14.0
# 109163    60  ...   11     3     1   10  RegSeason     14.0
# 109164    59  ...    8     5     3   17  RegSeason     14.0
# 109165    59  ...   12     8     1   16  RegSeason     14.0
# 109166    49  ...   14     6     1   26  RegSeason     14.0
# 109167    46  ...    7     5     5   20  RegSeason     14.0
# 109168    53  ...   12     8     0   13  RegSeason     14.0
# 109169    54  ...   14     7     5   15  RegSeason     14.0
# 109170    54  ...    6     7     4   18  RegSeason     14.0
# 109171    67  ...   10     7     5   15  RegSeason     14.0
# 109172    53  ...   16     8     8   19  RegSeason     14.0
# 109173    53  ...   10     6     2   11  RegSeason     14.0
# 109174    58  ...   11     5     4   17  RegSeason     14.0
# 109175    56  ...   12     4     1   18  RegSeason     14.0
# 109176    49  ...   12     5     4   22  RegSeason     14.0
# 109177    54  ...   11     7     1   18  RegSeason     14.0
# 109178    61  ...    6     2     1   12  RegSeason     14.0
# 109179    56  ...    7     1     1   22  RegSeason     14.0
# 109180    61  ...   14     6     3   10  RegSeason     14.0
# 109181    56  ...    8     7     6   19  RegSeason     14.0
# 109182    45  ...   19     5     2   20  RegSeason     14.0
# 109183    56  ...   15     2     2   14  RegSeason     14.0
# 109184    53  ...   17    10     1   22  RegSeason     14.0
# 109185    56  ...   15     6     2   25  RegSeason     14.0
# 109186    55  ...   16     6     5   19  RegSeason     14.0
# 109187    70  ...   16     7     6   15  RegSeason     14.0
# 109188    56  ...   14     6     0    9  RegSeason     14.0
# ...                   ...                ...          ...
# 109189     2022-14.0-1400     2022-14.0-1242         16.0
# 109190     2022-14.0-1411     2022-14.0-1126        194.0
# 109191     2022-14.0-1422     2022-14.0-1441        179.0
# 109192     2022-14.0-1438     2022-14.0-1181         69.0
# 109193     2022-14.0-1439     2022-14.0-1338         40.0
#
# [109194 rows x 39 columns]

# %%
# Rename OrdinalRank column to indicate it is for the winning team
results_df.rename(columns={'OrdinalRank': 'WOrdinalRank'},inplace=True)

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     136     1112      80     1436      51    N      0    31    66
# 3    2003     136     1112      80     1436      51    N      0    31    66
# 4    2003     136     1113      84     1272      71    N      0    31    59
#
#    ...  LAst  LTO  LStl  LBlk  LPF    GameType  WeekNum  WSeason-Week-Team  \
# 0  ...    16   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 1  ...    16   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 2  ...    12   17    10     3   15  Tournament     19.0     2003-19.0-1112
# 3  ...    12   17    10     3   15  Tournament     19.0     2003-19.0-1112
# 4  ...    11   12     2     5   18  Tournament     19.0     2003-19.0-1113
#
#    LSeason-Week-Team  WOrdinalRank
# 0     2003-19.0-1411         252.0
# 1     2003-19.0-1411         251.0
# 2     2003-19.0-1436           1.0
# 3     2003-19.0-1436           2.0
# 4     2003-19.0-1272          29.0
#
# [5 rows x 39 columns]

# %%
# Merge rankings for losing team into the original results_df
results_df = results_df.merge(SAG_ranks[['Season-Week-Team','OrdinalRank']], how='left', left_on='LSeason-Week-Team', right_on='Season-Week-Team')

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     134     1421      92     1411      84    N      1    32    69
# 3    2003     134     1421      92     1411      84    N      1    32    69
# 4    2003     136     1112      80     1436      51    N      0    31    66
#
#    ...  LStl  LBlk  LPF    GameType  WeekNum  WSeason-Week-Team  \
# 0  ...     5     0   22  Tournament     19.0     2003-19.0-1421
# 1  ...     5     0   22  Tournament     19.0     2003-19.0-1421
# 2  ...     5     0   22  Tournament     19.0     2003-19.0-1421
# 3  ...     5     0   22  Tournament     19.0     2003-19.0-1421
# 4  ...    10     3   15  Tournament     19.0     2003-19.0-1112
#
#    LSeason-Week-Team  WOrdinalRank  Season-Week-Team  OrdinalRank
# 0     2003-19.0-1411         252.0    2003-19.0-1411        262.0
# 1     2003-19.0-1411         252.0    2003-19.0-1411        257.0
# 2     2003-19.0-1411         251.0    2003-19.0-1411        262.0
# 3     2003-19.0-1411         251.0    2003-19.0-1411        257.0
# 4     2003-19.0-1436           1.0    2003-19.0-1436        166.0
#
# [5 rows x 41 columns]

# %%
# Drop unnecessary Season-Week_Team column
results_df.drop('Season-Week-Team',axis=1, inplace=True)

results_df
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0         2003     134     1421      92     1411      84    N      1    32
# 1         2003     134     1421      92     1411      84    N      1    32
# 2         2003     134     1421      92     1411      84    N      1    32
# 3         2003     134     1421      92     1411      84    N      1    32
# 4         2003     136     1112      80     1436      51    N      0    31
# ...        ...     ...      ...     ...      ...     ...  ...    ...   ...
# 124363    2022      98     1400      79     1242      76    H      0    28
# 124364    2022      98     1411      66     1126      63    A      0    24
# 124365    2022      98     1422      68     1441      49    A      0    23
# 124366    2022      98     1438      69     1181      68    A      0    31
# 124367    2022      98     1439      74     1338      47    H      0    29
#
#         WFGA  ...  LTO  LStl  LBlk  LPF    GameType  WeekNum  \
# 0         69  ...   15     5     0   22  Tournament     19.0
# 1         69  ...   15     5     0   22  Tournament     19.0
# 2         69  ...   15     5     0   22  Tournament     19.0
# 3         69  ...   15     5     0   22  Tournament     19.0
# 4         66  ...   17    10     3   15  Tournament     19.0
# ...      ...  ...  ...   ...   ...  ...         ...      ...
# 124363    67  ...   15     3     5   21   RegSeason     14.0
# 124364    59  ...   19    13     2   23   RegSeason     14.0
# 124365    56  ...   16     8     2   12   RegSeason     14.0
# 124366    65  ...   14     3     9   11   RegSeason     14.0
# 124367    55  ...   11     3     6   14   RegSeason     14.0
#
#         WSeason-Week-Team  LSeason-Week-Team  WOrdinalRank  OrdinalRank
# 0          2003-19.0-1421     2003-19.0-1411         252.0        262.0
# 1          2003-19.0-1421     2003-19.0-1411         252.0        257.0
# 2          2003-19.0-1421     2003-19.0-1411         251.0        262.0
# 3          2003-19.0-1421     2003-19.0-1411         251.0        257.0
# 4          2003-19.0-1112     2003-19.0-1436           1.0        166.0
# ...                   ...                ...           ...          ...
# 124363     2022-14.0-1400     2022-14.0-1242          16.0          6.0
# 124364     2022-14.0-1411     2022-14.0-1126         194.0        342.0
# 124365     2022-14.0-1422     2022-14.0-1441         179.0        289.0
# 124366     2022-14.0-1438     2022-14.0-1181          69.0         11.0
# 124367     2022-14.0-1439     2022-14.0-1338          40.0        145.0
#
# [124368 rows x 40 columns]

# %%
# Rename OrdinalRank column to indicate it is for the losing team
results_df.rename(columns={'OrdinalRank': 'LOrdinalRank'},inplace=True)

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     134     1421      92     1411      84    N      1    32    69
# 3    2003     134     1421      92     1411      84    N      1    32    69
# 4    2003     136     1112      80     1436      51    N      0    31    66
#
#    ...  LTO  LStl  LBlk  LPF    GameType  WeekNum  WSeason-Week-Team  \
# 0  ...   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 1  ...   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 2  ...   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 3  ...   15     5     0   22  Tournament     19.0     2003-19.0-1421
# 4  ...   17    10     3   15  Tournament     19.0     2003-19.0-1112
#
#    LSeason-Week-Team  WOrdinalRank  LOrdinalRank
# 0     2003-19.0-1411         252.0         262.0
# 1     2003-19.0-1411         252.0         257.0
# 2     2003-19.0-1411         251.0         262.0
# 3     2003-19.0-1411         251.0         257.0
# 4     2003-19.0-1436           1.0         166.0
#
# [5 rows x 40 columns]

# %%
# Add column for % field goals made
results_df['WFG%'] = results_df['WFGM']/results_df['WFGA']
results_df['LFG%'] = results_df['LFGM']/results_df['LFGA']

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     134     1421      92     1411      84    N      1    32    69
# 3    2003     134     1421      92     1411      84    N      1    32    69
# 4    2003     136     1112      80     1436      51    N      0    31    66
#
#    ...  LBlk  LPF    GameType  WeekNum  WSeason-Week-Team  LSeason-Week-Team  \
# 0  ...     0   22  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 1  ...     0   22  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 2  ...     0   22  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 3  ...     0   22  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 4  ...     3   15  Tournament     19.0     2003-19.0-1112     2003-19.0-1436
#
#    WOrdinalRank  LOrdinalRank      WFG%      LFG%
# 0         252.0         262.0  0.463768  0.432836
# 1         252.0         257.0  0.463768  0.432836
# 2         251.0         262.0  0.463768  0.432836
# 3         251.0         257.0  0.463768  0.432836
# 4           1.0         166.0  0.469697  0.312500
#
# [5 rows x 42 columns]

# %%
# Add column for % threes made
results_df['WFG3%'] = results_df['WFGM3']/results_df['WFGA3']
results_df['LFG3%'] = results_df['LFGM3']/results_df['LFGA3']

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     134     1421      92     1411      84    N      1    32    69
# 3    2003     134     1421      92     1411      84    N      1    32    69
# 4    2003     136     1112      80     1436      51    N      0    31    66
#
#    ...    GameType  WeekNum  WSeason-Week-Team  LSeason-Week-Team  \
# 0  ...  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 1  ...  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 2  ...  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 3  ...  Tournament     19.0     2003-19.0-1421     2003-19.0-1411
# 4  ...  Tournament     19.0     2003-19.0-1112     2003-19.0-1436
#
#    WOrdinalRank  LOrdinalRank      WFG%      LFG%     WFG3%     LFG3%
# 0         252.0         262.0  0.463768  0.432836  0.379310  0.387097
# 1         252.0         257.0  0.463768  0.432836  0.379310  0.387097
# 2         251.0         262.0  0.463768  0.432836  0.379310  0.387097
# 3         251.0         257.0  0.463768  0.432836  0.379310  0.387097
# 4           1.0         166.0  0.469697  0.312500  0.304348  0.250000
#
# [5 rows x 44 columns]

# %%
# Add a column for % FT made
results_df['WFT%'] = results_df['WFTM']/results_df['WFTA']
results_df['LFT%'] = results_df['LFTM']/results_df['LFTA']

results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     134     1421      92     1411      84    N      1    32    69
# 2    2003     134     1421      92     1411      84    N      1    32    69
# 3    2003     134     1421      92     1411      84    N      1    32    69
# 4    2003     136     1112      80     1436      51    N      0    31    66
#
#    ...  WSeason-Week-Team  LSeason-Week-Team  WOrdinalRank  LOrdinalRank  \
# 0  ...     2003-19.0-1421     2003-19.0-1411         252.0         262.0
# 1  ...     2003-19.0-1421     2003-19.0-1411         252.0         257.0
# 2  ...     2003-19.0-1421     2003-19.0-1411         251.0         262.0
# 3  ...     2003-19.0-1421     2003-19.0-1411         251.0         257.0
# 4  ...     2003-19.0-1112     2003-19.0-1436           1.0         166.0
#
#        WFG%      LFG%     WFG3%     LFG3%      WFT%      LFT%
# 0  0.463768  0.432836  0.379310  0.387097  0.653846  0.451613
# 1  0.463768  0.432836  0.379310  0.387097  0.653846  0.451613
# 2  0.463768  0.432836  0.379310  0.387097  0.653846  0.451613
# 3  0.463768  0.432836  0.379310  0.387097  0.653846  0.451613
# 4  0.469697  0.312500  0.304348  0.250000  0.785714  1.000000
#
# [5 rows x 46 columns]

# %%
results_df.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'GameType', 'WeekNum', 'WSeason-Week-Team', 'LSeason-Week-Team',
#        'WOrdinalRank', 'LOrdinalRank', 'WFG%', 'LFG%', 'WFG3%', 'LFG3%',
#        'WFT%', 'LFT%'],
#       dtype='object')

# %%
results_df['WOrdinalRank'].isna().sum()
# Out:
# 8881

# %%
SAG_ranks['WeekNum'].max()
# Out:
# 19.0

# %%
# Export results to csv
results_df.to_csv('detailed_all_game_results.csv', index=False)
